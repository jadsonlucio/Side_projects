# %%
from lol_api.lol_dataset import api

test=api("files/ranked_dataset.csv")
test.decomposition("pca",test.Dataset_numerico.columns,3,{"random_state":0})
test.plot_cluster()
